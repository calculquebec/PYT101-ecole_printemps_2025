# %% [markdown]
# # Fichiers, conditions et boucles
#
# ## Objectifs :
# ## - Savoir utiliser une boucle `for`
# ## - Savoir utiliser la déclaration conditionnelle `if`
# ## - Explorer les différentes façons de lire des fichiers
#
# On commence réellement à apprécier les gains en rapidité de la programmation avec Python quand on arrive à sauver du temps grâce aux boucles. Celles-ci nous permettent d'effectuer une même séquence d'opérations sur différents fichiers avec quelques lignes de code seulement.
#
# ### Structure d'une boucle
#
# <p align="center">
#   <img src="fig/boucle.png" alt="Photo centrée" width="600">
# </p>
#
# Chaque boucle débute par `for i in iterable :`
# - `i` : Le nom de la variable `i` n'a aucune importance, on aurait pu l'appeler n'importe comment (exemple : `for animal in zoo :`) !
# - Exemples d'objets itérables :
#   - Les listes : `['a', 'b', 'c']`
#   - Les chaînes de caractères : `"bonjour"`
#   - Les dictionnaires : `{"clé": "valeur"}`
#   - Les ensembles (sets) : `{1, 2, 3}`
#   - Les objets retournés par une fonction comme `range()`
#   - Les fichiers
# - On termine la ligne avec un `:`. En Python, on met un `:` pour signaler le début d'un bloc (comme les boucles, les conditions, ou les contextes avec `with`), puis on **indente** le code qui en fait partie. Dans un notebook, l'indentation se fait automatiquement si le `:` a bien été ajouté.
#
# Corps de la boucle :
# - Toute action qui doit être réalisée sur chaque élément de l'itérable, un à la fois (opération mathématique, transformation, figure, etc.)
# - Python comprend par lui même quand il est arrivé à la fin de l'itérable et quitte automatiquement la boucle.

# %%
for lettre in 'anticonstitutionnellement' :
    print(lettre.upper())
# Out:
# A
# N
# T
# I
# C
# O
# N
# S
# T
# I
# T
# U
# T
# I
# O
# N
# N
# E
# L
# L
# E
# M
# E
# N
# T

# %% [markdown]
# Exercice
#
# Écrivez une boucle qui permet d'obtenir la puissance au carré de tous les nombres de la liste `nombres`.

# %%
nombres = [4, 8, 14, 20, 33, 100]

#

# %% [markdown]
# Exercice
#
# Imprimez la première lettre de chaque valeur du dictionnaire `capitales`.

# %%
capitales = {'France': 'Paris',
             'Canada': 'Ottawa',
             'Italie': 'Rome',
             'Espagne': 'Madrid',
             'Thaïlande': 'Bangkok'}

#

# %% [markdown]
# ### Déclaration conditionnelle `if`
#
# La déclaration conditionnelle `if` en Python permet d'exécuter un bloc de code **seulement si** une condition est vraie. C’est un élément fondamental pour introduire la logique de décisionnelle dans un programme.
#
# - Syntaxe de base
#
# `if condition :`
# <p style="margin-left: 40px;">
# <code># bloc de code exécuté si la condition est vraie
# </p>
#
# - Comme pour les boucles et la déclaration `with()`, le code suivant la déclaration `if` doit être indenté.
#
# - Conditions possibles : On peut utiliser des opérateurs de comparaison
#
#   - == : égal
#   - != : différent
#   - <, >, <=, >= : inférieurs / supérieurs
#   - and, or, not : opérateurs logiques
#   - in : vérifier si un élément existe dans une séquence (liste, chaîne, dictionnaire)
#
# Si l'énoncé est égal à `True`, il s'exécute :

# %%
age = 18

if age >= 18:
    print("Vous êtes majeur.")
# Out:
# Vous êtes majeur.

# %% [markdown]
# Si l'énoncé est égal à `False`, il ne s'exécute pas :

# %%
nombre = 11
if nombre <= 10:
    print('Le nombre était plus petit que 10')

# %%
fin_de_semaine = ['samedi','dimanche']

if 'lundi' in fin_de_semaine :
    print('Cette journée fait partie de la fin de semaine')

# %% [markdown]
# On peut ajouter du code à exécuter si la condition `if` retourne `False` avec l'énoncé `else`.

# %%
fin_de_semaine = ['samedi','dimanche']

if 'lundi' in fin_de_semaine :
    print('Cette journée fait partie de la fin de semaine')
else :
    print('Cette journée fait partie de la semaine')
# Out:
# Cette journée fait partie de la semaine

# %% [markdown]
# Exercice
#
# Utilisez la déclaration `if` pour déterminer si `'bra'` est dans `'abracadabra'`.

# %%
#

# %% [markdown]
# Utilisez la déclaration `if` pour déterminer si 24 est un nombre pair.

# %%
#

# %% [markdown]
# ### On peut ensuite combiner les boucles et la déclaration `if`

# %%
semaine_complete = ['lundi', 'mardi','mercredi','jeudi','vendredi','samedi','dimanche']

for jour in semaine_complete :
    if jour in fin_de_semaine :
        print(jour)
# Out:
# samedi
# dimanche

# %% [markdown]
# Exercice
#
# Afficher les nombres de 1 à 10 et indiquer s'ils sont pairs ou impairs

# %%
#

# %% [markdown]
# Filtrer les mots de la liste `mots` qui commencent par une voyelle

# %%
mots = ['chat', 'avion', 'tapis', 'soleil', 'orange',
        'livre', 'robot', 'usine', 'banane', 'papillon',
        'pomme', 'stylo', 'igloo', 'montagne', 'escalier']

#

# %% [markdown]
# ### Lecture de fichiers
#
# - Fichiers **tabulaires** (CSV, Excel, JSON, XML). Ces fichiers sont facilement lus et manipulables avec le paquet `pandas`. Vous apprendrez à utiliser ce paquet davantage dans la prochaine formation, mais voici un aperçu.

# %%
import pandas as pd

# %%
# source des données : 
# https://www.donneesquebec.ca/recherche/dataset/reseau-wifi/resource/2a451b5f-cbe9-4dcb-b9e5-03e63ababcad
# Localisation des points d'accès à un réseau wifi gratuit
wifi = pd.read_csv("data/zap.csv")

# %%
wifi
# Out:
#     OBJECTID  MUNICIPALITE                                    NOM_LIEU  \
# 0          1         10043                Aérogare Paul-Émile-Lapointe
# 1          3         10043                         Bibliothèque Le Bic
# 2          4         10043                  Bibliothèque Pascal-Parent
# 3          5         10043              Bibliothèque de Pointe-au-Père
# 4          6         10043         Centre communautaire Pointe-au-Père
# 5          7         10043           Centre communautaire Rimouski-Est
# 6          8         10043           Centre communautaire Saint-Robert
# 7          9         10043           Centre communautaire Sainte-Odile
# 8         10         10043      Centre communautaire Sainte-Agnès Nord
# 9         11         10043            Centre communautaire Sacré-Coeur
# 10        12         10043                             Parc Beauséjour
# 11        14         10043                Parc des Anciens Combattants
# 12        15         10043                   Salle du Conseil de ville
# 13        16         10043                           Tourisme Rimouski
# 14        17         10043                             Café des Halles
# 15        18         10043        Pâtisseries & Gourmandises d'Olivier
# 16        19         10043                           La Brûlerie d'ici
# 17        20         10043                              Le Presse Café
# 18        22         10043                           Cégep de Rimouski
# 19        23         10043   Collectif de Développement Régional (CRD)
# 20        24         10043                               Crêpe Chignon
# 21        25         10043                      La SADC de la Neigette
# 22        26         10043            Centre communautaire Saint-Pie-X
# 23        27         10043  Centre communautaire Terrasse Arthur-Buies
# 24        28         10043                           Centre Curé-Soucy
# 25        30         10043                     Pavillon de la Jeunesse
# 26        31         10043               Centre communautaire Nazareth
# 27        32         10043                       Restaurant Chez Oeufs
# 28        33         10043       Chocolaterie Pâtisserie aux Bienfaits
# 29        34         10043                       Piscine Saint-Germain
# 30        35         10043                         Pavillon Polyvalent
# 31        36         10043       Centre Communautaire Sainte-Agnès Sud
#
#        XNAD83MTM6    YNAD83MTM6 NOM_RESEAU  \
# 0   230505.082000  5.371305e+06     ZAPBSL
# 1   215492.147150  5.359866e+06     ZAPBSL
# 2   233578.218500  5.358377e+06     ZAPBSL
# 3   233952.538300  5.375159e+06     ZAPBSL
# 4   234177.365700  5.374441e+06     ZAPBSL
# 5   230853.558300  5.371618e+06     ZAPBSL
# 6   228852.967600  5.367115e+06     ZAPBSL
# 7   227452.663400  5.366443e+06     ZAPBSL
# 8   229744.911600  5.369569e+06     ZAPBSL
# 9   224050.239300  5.366101e+06     ZAPBSL
# 10  227918.207400  5.366957e+06     ZAPBSL
# 11  228650.678300  5.368552e+06     ZAPBSL
# 12  228984.462700  5.368339e+06     ZAPBSL
# 13  228578.473200  5.368512e+06     ZAPBSL
# 14  228397.437300  5.368320e+06     ZAPBSL
# 15  229036.233350  5.368744e+06     ZAPBSL
# 16  228462.528300  5.368383e+06     ZAPBSL
# 17  228338.232600  5.368347e+06     ZAPBSL
# 18  228789.510125  5.368234e+06     ZAPBSL
# 19  228481.976000  5.367867e+06     ZAPBSL
# 20  228847.042300  5.368537e+06     ZAPBSL
# 21  229296.943600  5.368511e+06     ZAPBSL
# 22  230549.646500  5.368456e+06     ZAPBSL
# 23  228839.845400  5.366259e+06     ZAPBSL
# 24  215577.202100  5.359895e+06     ZAPBSL
# 25  233772.419850  5.358366e+06     ZAPBSL
# 26  227015.130000  5.367507e+06     ZAPBSL
# 27  228321.596700  5.368265e+06     ZAPBSL
# 28  229053.057700  5.368279e+06     ZAPBSL
# 29  229163.371300  5.368146e+06     ZAPBSL
# 30  229283.309700  5.367998e+06     ZAPBSL
# 31  230461.853775  5.369260e+06     ZAPBSL
#
#                               MOT_PASSE  \
# 0   Mot de passe attribué par la Z.A.P.
# 1   Mot de passe attribué par la Z.A.P.
# 2   Mot de passe attribué par la Z.A.P.
# 3   Mot de passe attribué par la Z.A.P.
# 4   Mot de passe attribué par la Z.A.P.
# 5   Mot de passe attribué par la Z.A.P.
# 6   Mot de passe attribué par la Z.A.P.
# 7   Mot de passe attribué par la Z.A.P.
# 8   Mot de passe attribué par la Z.A.P.
# 9   Mot de passe attribué par la Z.A.P.
# 10  Mot de passe attribué par la Z.A.P.
# 11  Mot de passe attribué par la Z.A.P.
# 12  Mot de passe attribué par la Z.A.P.
# 13  Mot de passe attribué par la Z.A.P.
# 14  Mot de passe attribué par la Z.A.P.
# 15  Mot de passe attribué par la Z.A.P.
# 16  Mot de passe attribué par la Z.A.P.
# 17  Mot de passe attribué par la Z.A.P.
# 18  Mot de passe attribué par la Z.A.P.
# 19  Mot de passe attribué par la Z.A.P.
# 20  Mot de passe attribué par la Z.A.P.
# 21  Mot de passe attribué par la Z.A.P.
# 22  Mot de passe attribué par la Z.A.P.
# 23  Mot de passe attribué par la Z.A.P.
# 24  Mot de passe attribué par la Z.A.P.
# 25  Mot de passe attribué par la Z.A.P.
# 26  Mot de passe attribué par la Z.A.P.
# 27  Mot de passe attribué par la Z.A.P.
# 28  Mot de passe attribué par la Z.A.P.
# 29  Mot de passe attribué par la Z.A.P.
# 30  Mot de passe attribué par la Z.A.P.
# 31  Mot de passe attribué par la Z.A.P.
#
#                                   DETAILS                  FOURNISSEUR   GEOM  \
# 0   http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 1   http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 2   http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 3   http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 4   http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 5   http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 6   http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 7   http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 8   http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 9   http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 10  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 11  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 12  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 13  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 14  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 15  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 16  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 17  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 18  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 19  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 20  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 21  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 22  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 23  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 24  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 25  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 26  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 27  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 28  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 29  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 30  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
# 31  http://zapbsl.org/pour-vous-brancher/  Z.A.P. du Bas-Saint-Laurent  Point
#
#                                   GlobalID
# 0   {19D286B3-EB0C-4F0A-9B3F-FC422C7A9609}
# 1   {DD1B718B-BCA1-45A6-B057-6C338088B446}
# 2   {96705019-6A7C-4D48-A09C-0F4CCC7E9D51}
# 3   {D69F8D5B-A943-4A15-ACCF-14CB9B1C1BB0}
# 4   {FFC4734D-8CFA-4C5A-A8A7-E679831D9D85}
# 5   {AB47233B-34C5-4A43-86BE-98C2ACBC1D3D}
# 6   {D38B053D-F45A-4173-BC71-24C3B9484BDC}
# 7   {3C6784EF-8973-48BE-8C89-E08D534C50A6}
# 8   {2502107C-1F6A-430B-9960-E39B83636824}
# 9   {38C62553-D50E-4914-BE40-D005E9DE0400}
# 10  {68CC8DD1-FF81-47A3-A850-E55F23C7B3B7}
# 11  {68177DB7-8932-4EA5-957F-6066790312CE}
# 12  {A85A5C2E-5DA0-4E0C-B6AE-4CAA0AD661E8}
# 13  {D7F80812-3032-404B-8357-3D070220382A}
# 14  {0A00C5C2-9EE1-4FAB-8833-BD2880D5E7AC}
# 15  {64FB112E-1E25-4B8D-B8BA-345B8CDC4C3E}
# 16  {2B881EC3-9755-494E-B6EB-21A24CE46B4D}
# 17  {F966C404-1EEE-4448-8AB6-0EBAC744352F}
# 18  {D91AC98F-3B98-4038-A6A2-4AF81569DDA1}
# 19  {54F4A959-A408-4862-B487-622077E6B46A}
# 20  {E36C27E3-E705-4866-88D7-E084208942A4}
# 21  {3838B594-4760-4AC4-84FF-79A20D2555CC}
# 22  {03F42509-63F7-44B8-A802-5389B91CDD7F}
# 23  {FCE9DCB8-CC7E-43C4-A914-8BD13EBF6988}
# 24  {165FEDB5-6A06-404C-BCBF-DAF386B0293D}
# 25  {E9471435-CBDC-47AA-8B44-67D45D542394}
# 26  {D924C297-4A19-48DD-A9FD-48562697388D}
# 27  {B4DBABFF-A7EE-4A6A-BAE2-CC65882B643A}
# 28  {0C9EA8A3-81C5-4B9E-B587-0ADBC7B9762B}
# 29  {F269D1C6-8987-40C9-A0DF-972CCDC6FEAA}
# 30  {74CF810F-F5A7-484C-A274-CD83EC96201C}
# 31  {8E26A9AB-905E-469A-96A9-7377115078EE}

# %%
type(wifi)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - Fichiers **textes** au format **atypique** : Ces types de fichiers demandent plus de travail manuel pour structurer les données, car ils ne sont pas tabulaires ou les lignes ne sont pas uniformes. Des exemples de formats de fichiers incluent les données biologiques (ex : FASTA, FASTQ, GBK) et les fichiers textes (.txt). Ils doivent être lus avec la fonction `open()`.

# %%
animaux = []
with open('data/liste_animaux.txt', 'r') as f :
    for line in f :
        line = line.strip()
        animaux.append(line)

# %% [markdown]
# Décortiquons chaque ligne de cette cellule de code :
#
# 1. `animaux = []`
# - On crée d'abord une liste vide, appelée `animaux`. Cette liste va contenir les noms d’animaux lus dans le fichier.
#
# 2. `with open('liste_animaux.txt', 'r') as f :`
# - La déclaration `with` avant la fonction `open()` garantit que le fichier est correctement fermé, même en cas d'erreurs.
# - Les paramètres de fonction `open()` spécifient :
#   - le fichier à lire (et le chemin vers son répertoire, le cas échéant) : `'liste_animaux.txt'`
#   - le mode d'ouverture : `'r'` pour lire le fichier, `'w'` pour écrire un nouveau fichier, `'a'` pour ajouter à un fichier déjà existant
# - L'expression `as f` sert à donner un nom à l’objet fichier que Python retourne lorsqu’il ouvre le fichier. Cet objet permet ensuite d’interagir avec le fichier. Le nom `f` n'a aucune importance, on aurait pu l'appeler `banane` !
# - On termine la ligne 2 avec un `:`, ce qui indique le début d’un bloc qu'on indente (comme pour la boucle).
#
# 3. `for line in f :`
#
# Parcourt chaque ligne du fichier f, une à une. À chaque tour de boucle, la variable `line` contient une ligne du fichier. De la même manière que `f` aurait pu être appelé `banane`, `line` peut prendre n'importe quel nom.
#
# 4. `line = line.strip()`
#
# La commande `strip()` supprime les espaces, tabulations, et surtout les sauts de ligne (\n) en début et fin de ligne. Cela permet d’avoir une chaîne propre (juste le nom de l’animal).
#
# 5. `animaux.append(line)`
#
# La commande `append()` ajoute la ligne nettoyée (le nom d’un animal) à la liste `animaux`.

# %%
animaux
# Out:
# ['ours',
#  'chien',
#  'zèbre',
#  'tigre',
#  'ours',
#  'zèbre',
#  'zèbre',
#  'tigre',
#  'éléphant',
#  'chat',
#  'tigre',
#  'loup',
#  'tigre',
#  'loup',
#  'chat',
#  'loup',
#  'ours',
#  'éléphant',
#  'tigre',
#  'tigre',
#  'ours',
#  'cheval',
#  'chat',
#  'loup',
#  'tigre',
#  'cheval',
#  'loup',
#  'zèbre',
#  'chat',
#  'zèbre',
#  'lion',
#  'tigre',
#  'chat',
#  'girafe',
#  'chat',
#  'cheval',
#  'girafe',
#  'tigre',
#  'zèbre',
#  'ours',
#  'ours',
#  'zèbre',
#  'girafe',
#  'tigre',
#  'zèbre',
#  'cheval',
#  'chat',
#  'tigre',
#  'éléphant',
#  'chien',
#  'chien',
#  'loup',
#  'tigre',
#  'lion',
#  'chat',
#  'tigre',
#  'tigre',
#  'éléphant',
#  'tigre',
#  'loup',
#  'lion',
#  'chien',
#  'tigre',
#  'tigre',
#  'loup',
#  'chat',
#  'zèbre',
#  'zèbre',
#  'chat',
#  'chat',
#  'tigre',
#  'chien',
#  'zèbre',
#  'zèbre',
#  'zèbre',
#  'éléphant',
#  'lion',
#  'tigre',
#  'cheval',
#  'girafe',
#  'loup',
#  'éléphant',
#  'girafe',
#  'éléphant',
#  'tigre',
#  'cheval',
#  'loup',
#  'éléphant',
#  'loup',
#  'lion',
#  'zèbre',
#  'zèbre',
#  'tigre',
#  'chat',
#  'chat',
#  'chien',
#  'tigre',
#  'zèbre',
#  'loup',
#  'ours',
#  'girafe',
#  'tigre',
#  'girafe',
#  'chien',
#  'zèbre',
#  'tigre',
#  'loup',
#  'chien',
#  'loup',
#  'zèbre',
#  'cheval',
#  'tigre',
#  'zèbre',
#  'ours',
#  'loup',
#  'chien',
#  'éléphant',
#  'zèbre',
#  'zèbre',
#  'zèbre',
#  'loup',
#  'loup',
#  'chat',
#  'tigre',
#  'ours',
#  'zèbre',
#  'loup',
#  'chat',
#  'chien',
#  'girafe',
#  'chat',
#  'zèbre',
#  'tigre',
#  'zèbre',
#  'tigre',
#  'chien',
#  'loup',
#  'zèbre',
#  'tigre',
#  'lion',
#  'loup',
#  'loup',
#  'éléphant',
#  'loup',
#  'girafe',
#  'éléphant',
#  'chat',
#  'chien',
#  'loup',
#  'loup',
#  'chat',
#  'lion',
#  'chat',
#  'chat',
#  'chien',
#  'lion',
#  'loup',
#  'zèbre',
#  'cheval',
#  'zèbre',
#  'cheval',
#  'tigre',
#  'loup',
#  'lion',
#  'chat',
#  'zèbre',
#  'éléphant',
#  'tigre',
#  'chien',
#  'ours',
#  'ours',
#  'chien',
#  'zèbre',
#  'chat',
#  'cheval',
#  'lion',
#  'loup',
#  'tigre',
#  'cheval',
#  'loup',
#  'cheval',
#  'cheval',
#  'zèbre',
#  'ours',
#  'zèbre',
#  'zèbre',
#  'tigre',
#  'lion',
#  'girafe',
#  'girafe',
#  'tigre',
#  'tigre',
#  'chat',
#  'zèbre',
#  'ours',
#  'chien',
#  'zèbre',
#  'loup',
#  'tigre',
#  'chat',
#  'tigre',
#  'tigre',
#  'ours',
#  'chat',
#  'girafe',
#  'chat',
#  'loup',
#  'chien',
#  'ours',
#  'zèbre',
#  'tigre',
#  'zèbre',
#  'zèbre',
#  'tigre',
#  'zèbre',
#  'tigre',
#  'girafe',
#  'loup',
#  'éléphant',
#  'zèbre',
#  'ours',
#  'chat',
#  'éléphant',
#  'éléphant',
#  'chat',
#  'girafe',
#  'lion',
#  'tigre',
#  'tigre',
#  'ours',
#  'cheval',
#  'chien',
#  'tigre',
#  'tigre',
#  'zèbre',
#  'éléphant',
#  'tigre',
#  'zèbre',
#  'girafe',
#  'zèbre',
#  'loup',
#  'zèbre',
#  'zèbre',
#  'loup',
#  'lion',
#  'tigre',
#  'zèbre',
#  'tigre',
#  'lion',
#  'cheval',
#  'zèbre',
#  'éléphant',
#  'tigre',
#  'loup',
#  'lion',
#  'zèbre',
#  'zèbre',
#  'tigre',
#  'loup',
#  'tigre',
#  'zèbre',
#  'cheval',
#  'tigre',
#  'loup',
#  'chat',
#  'tigre',
#  'girafe',
#  'ours',
#  'tigre',
#  'tigre',
#  'girafe',
#  'loup',
#  'girafe',
#  'tigre',
#  'loup',
#  'ours',
#  'chat',
#  'cheval',
#  'chat',
#  'éléphant',
#  'chien',
#  'lion',
#  'cheval',
#  'lion',
#  'zèbre',
#  'zèbre',
#  'tigre',
#  'chat',
#  'tigre',
#  'zèbre',
#  'chien',
#  'girafe',
#  'loup',
#  'zèbre',
#  'loup',
#  'loup',
#  'zèbre',
#  'éléphant',
#  'chat',
#  'girafe',
#  'chien',
#  'lion',
#  'ours',
#  'tigre',
#  'chat',
#  'cheval',
#  'chat',
#  'girafe',
#  'girafe',
#  'loup',
#  'lion',
#  'zèbre',
#  'ours',
#  'chien',
#  'ours',
#  'zèbre',
#  'ours',
#  'loup',
#  'zèbre',
#  'zèbre',
#  'tigre',
#  'tigre',
#  'éléphant',
#  'loup',
#  'zèbre',
#  'ours',
#  'zèbre',
#  'tigre',
#  'éléphant',
#  'girafe',
#  'zèbre',
#  'zèbre',
#  'girafe',
#  'ours',
#  'loup',
#  'lion',
#  'chat',
#  'tigre',
#  'éléphant',
#  'chat',
#  'tigre',
#  'cheval',
#  'ours',
#  'zèbre',
#  'éléphant',
#  'tigre',
#  'zèbre',
#  'chat',
#  'tigre',
#  'zèbre',
#  'zèbre',
#  'tigre',
#  'zèbre',
#  'loup',
#  'cheval',
#  'chien',
#  'zèbre',
#  'zèbre',
#  'ours',
#  'lion',
#  'girafe',
#  'tigre',
#  'cheval',
#  'girafe',
#  'zèbre',
#  'zèbre',
#  'girafe',
#  'loup',
#  'zèbre',
#  'éléphant',
#  'cheval',
#  'tigre',
#  'tigre',
#  'loup',
#  'tigre',
#  'tigre',
#  'tigre',
#  'chien',
#  'tigre',
#  'loup',
#  'zèbre',
#  'zèbre',
#  'chat',
#  'chat',
#  'loup',
#  'zèbre',
#  'loup',
#  'chat',
#  'cheval',
#  'tigre',
#  'tigre',
#  'tigre',
#  'girafe',
#  'loup',
#  'tigre',
#  'tigre',
#  'ours',
#  'loup',
#  'tigre',
#  'éléphant',
#  'girafe',
#  'cheval']

# %% [markdown]
# Exercice
#
# Lire chaque ligne du fichier `prenom_age.txt`, extraire l'âge et afficher les personnes de plus de 30 ans.

# %%
#

# %% [markdown]
# Exercice
#
# Lire le fichier `temperature_avril.txt` et calculer la moyenne de température.

# %%
#

# %% [markdown]
# ### Finalement, on peut aussi appliquer la boucle `for` pour lire plusieurs fichiers en lot.

# %% [markdown]
# Défi !
#
# Complétez le code suivant qui permet de lire tous les fichiers avec l'extension `.fasta` et de stocker toutes les séquences dans un seul dictionnaire.

# %%
import glob

filename = (glob.glob('data/*.fasta'))

#
